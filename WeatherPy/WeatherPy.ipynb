# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&units=metric&q=" + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | buchanan
# Processing Record 2 of Set 1 | klaksvik
# Processing Record 3 of Set 1 | mahebourg
# Processing Record 4 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 1 | mitzic
# Processing Record 6 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | cabo san lucas
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | puerto princesa
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | nelson bay
# Processing Record 15 of Set 1 | lingyuan
# Processing Record 16 of Set 1 | churumuco
# City not found. Skipping...
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | san quintin
# Processing Record 19 of Set 1 | nome
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | faya
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 1 | pitsunda
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | nizwa
# Processing Record 27 of Set 1 | wukari
# Processing Record 28 of Set 1 | sosnovo-ozerskoye
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | ayan
# Processing Record 33 of Set 1 | kaitangata
# Processing Record 34 of Set 1 | zyryanka
# Processing Record 35 of Set 1 | havre-saint-pierre
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | katsuura
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | constitucion
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | camopi
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | turukhansk
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | evensk
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | codrington
# Processing Record 0 of Set 2 | avarua
# Processing Record 1 of Set 2 | lavrentiya
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | angra
# City not found. Skipping...
# Processing Record 4 of Set 2 | saint george
# Processing Record 5 of Set 2 | valera
# Processing Record 6 of Set 2 | marsa matruh
# Processing Record 7 of Set 2 | sorland
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | faanui
# Processing Record 10 of Set 2 | parabel
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | clyde river
# Processing Record 13 of Set 2 | pascagoula
# Processing Record 14 of Set 2 | esperance
# Processing Record 15 of Set 2 | santa cruz
# Processing Record 16 of Set 2 | hasaki
# Processing Record 17 of Set 2 | kruisfontein
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | atikokan
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | upernavik
# Processing Record 22 of Set 2 | jiujiang
# Processing Record 23 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 2 | touros
# Processing Record 25 of Set 2 | almeria
# Processing Record 26 of Set 2 | longyearbyen
# Processing Record 27 of Set 2 | preobrazheniye
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | sambava
# Processing Record 30 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 2 | sharan
# Processing Record 32 of Set 2 | bambous virieux
# Processing Record 33 of Set 2 | sibolga
# Processing Record 34 of Set 2 | luderitz
# Processing Record 35 of Set 2 | gravelbourg
# Processing Record 36 of Set 2 | wangkui
# Processing Record 37 of Set 2 | chokurdakh
# Processing Record 38 of Set 2 | winnemucca
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | at-bashi
# Processing Record 41 of Set 2 | ilulissat
# Processing Record 42 of Set 2 | ust-kuyga
# Processing Record 43 of Set 2 | chuy
# Processing Record 44 of Set 2 | ribeira grande
# Processing Record 45 of Set 2 | provideniya
# Processing Record 46 of Set 2 | pisco
# Processing Record 47 of Set 2 | lompoc
# Processing Record 48 of Set 2 | baykit
# Processing Record 49 of Set 2 | port hardy
# Processing Record 0 of Set 3 | adrar
# Processing Record 1 of Set 3 | mayna
# Processing Record 2 of Set 3 | mount isa
# Processing Record 3 of Set 3 | mount pleasant
# Processing Record 4 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 3 | gualaquiza
# Processing Record 6 of Set 3 | carutapera
# Processing Record 7 of Set 3 | hofn
# Processing Record 8 of Set 3 | coquimbo
# Processing Record 9 of Set 3 | diego de almagro
# Processing Record 10 of Set 3 | teguldet
# Processing Record 11 of Set 3 | manakara
# Processing Record 12 of Set 3 | kaeo
# Processing Record 13 of Set 3 | ngunguru
# Processing Record 14 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 3 | charters towers
# Processing Record 16 of Set 3 | luanda
# Processing Record 17 of Set 3 | outjo
# Processing Record 18 of Set 3 | belmonte
# Processing Record 19 of Set 3 | saint-philippe
# Processing Record 20 of Set 3 | samdari
# Processing Record 21 of Set 3 | shimanovsk
# Processing Record 22 of Set 3 | edson
# Processing Record 23 of Set 3 | torbay
# Processing Record 24 of Set 3 | ponta do sol
# Processing Record 25 of Set 3 | kahului
# Processing Record 26 of Set 3 | sokolac
# Processing Record 27 of Set 3 | yulara
# Processing Record 28 of Set 3 | barrow
# Processing Record 29 of Set 3 | iqaluit
# Processing Record 30 of Set 3 | geraldton
# Processing Record 31 of Set 3 | new norfolk
# Processing Record 32 of Set 3 | smithers
# Processing Record 33 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 3 | yenagoa
# Processing Record 35 of Set 3 | bluff
# Processing Record 36 of Set 3 | hobart
# Processing Record 37 of Set 3 | changping
# Processing Record 38 of Set 3 | fairbanks
# Processing Record 39 of Set 3 | lebu
# Processing Record 40 of Set 3 | arraial do cabo
# Processing Record 41 of Set 3 | henties bay
# Processing Record 42 of Set 3 | primero de enero
# Processing Record 43 of Set 3 | puerto carreno
# Processing Record 44 of Set 3 | barra do garcas
# Processing Record 45 of Set 3 | anadyr
# Processing Record 46 of Set 3 | khartoum
# Processing Record 47 of Set 3 | sur
# Processing Record 48 of Set 3 | ugoofaaru
# Processing Record 49 of Set 3 | cassilandia
# Processing Record 0 of Set 4 | pitimbu
# Processing Record 1 of Set 4 | sobolevo
# Processing Record 2 of Set 4 | rabo de peixe
# Processing Record 3 of Set 4 | kutum
# Processing Record 4 of Set 4 | dongsheng
# Processing Record 5 of Set 4 | mount gambier
# Processing Record 6 of Set 4 | sayyan
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | wad rawah
# Processing Record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 4 | east london
# Processing Record 11 of Set 4 | saint-denis
# Processing Record 12 of Set 4 | margate
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | stromness
# Processing Record 15 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 4 | kinshasa
# Processing Record 18 of Set 4 | padang
# Processing Record 19 of Set 4 | beira
# Processing Record 20 of Set 4 | zyryanskoye
# Processing Record 21 of Set 4 | kangaatsiaq
# Processing Record 22 of Set 4 | shahreza
# Processing Record 23 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 4 | maneadero
# Processing Record 25 of Set 4 | doha
# Processing Record 26 of Set 4 | lac du bonnet
# Processing Record 27 of Set 4 | yining
# Processing Record 28 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 29 of Set 4 | ostrovnoy
# Processing Record 30 of Set 4 | kuching
# Processing Record 31 of Set 4 | pen
# Processing Record 32 of Set 4 | komsomolskiy
# Processing Record 33 of Set 4 | tuatapere
# Processing Record 34 of Set 4 | tazovskiy
# Processing Record 35 of Set 4 | fare
# Processing Record 36 of Set 4 | misratah
# Processing Record 37 of Set 4 | husavik
# Processing Record 38 of Set 4 | sakaiminato
# Processing Record 39 of Set 4 | calama
# Processing Record 40 of Set 4 | itoman
# Processing Record 41 of Set 4 | alvaraes
# Processing Record 42 of Set 4 | bredasdorp
# Processing Record 43 of Set 4 | marsaxlokk
# Processing Record 44 of Set 4 | brigham city
# Processing Record 45 of Set 4 | praia da vitoria
# Processing Record 46 of Set 4 | avera
# Processing Record 47 of Set 4 | narsaq
# Processing Record 48 of Set 4 | nemuro
# Processing Record 49 of Set 4 | baherden
# Processing Record 0 of Set 5 | cabedelo
# Processing Record 1 of Set 5 | hamilton
# Processing Record 2 of Set 5 | itarema
# Processing Record 3 of Set 5 | andevoranto
# City not found. Skipping...
# Processing Record 4 of Set 5 | panzhihua
# Processing Record 5 of Set 5 | urucui
# Processing Record 6 of Set 5 | oktyabrskiy
# Processing Record 7 of Set 5 | souillac
# Processing Record 8 of Set 5 | khatanga
# Processing Record 9 of Set 5 | uvalde
# Processing Record 10 of Set 5 | ninghai
# Processing Record 11 of Set 5 | iskateley
# Processing Record 12 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 13 of Set 5 | skibbereen
# Processing Record 14 of Set 5 | biak
# Processing Record 15 of Set 5 | ornskoldsvik
# Processing Record 16 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 5 | ous
# Processing Record 18 of Set 5 | fort nelson
# Processing Record 19 of Set 5 | rindal
# Processing Record 20 of Set 5 | boguchany
# Processing Record 21 of Set 5 | zhangye
# Processing Record 22 of Set 5 | mayo
# Processing Record 23 of Set 5 | talnakh
# Processing Record 24 of Set 5 | kodiak
# Processing Record 25 of Set 5 | ondjiva
# Processing Record 26 of Set 5 | bayir
# Processing Record 27 of Set 5 | nikolayevka
# Processing Record 28 of Set 5 | dotnuva
# Processing Record 29 of Set 5 | nieuw nickerie
# Processing Record 30 of Set 5 | fayaoue
# Processing Record 31 of Set 5 | san luis
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | ledyard
# Processing Record 34 of Set 5 | castro
# Processing Record 35 of Set 5 | salalah
# Processing Record 36 of Set 5 | college
# Processing Record 37 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 5 | mahesana
# Processing Record 39 of Set 5 | aksu
# Processing Record 40 of Set 5 | tuktoyaktuk
# Processing Record 41 of Set 5 | sola
# Processing Record 42 of Set 5 | georgetown
# Processing Record 43 of Set 5 | yuma
# Processing Record 44 of Set 5 | peniche
# Processing Record 45 of Set 5 | buariki
# City not found. Skipping...
# Processing Record 46 of Set 5 | am timan
# Processing Record 47 of Set 5 | nouadhibou
# Processing Record 48 of Set 5 | mujiayingzi
# Processing Record 49 of Set 5 | thul
# Processing Record 0 of Set 6 | makung
# City not found. Skipping...
# Processing Record 1 of Set 6 | kalabo
# Processing Record 2 of Set 6 | aitape
# Processing Record 3 of Set 6 | dauriya
# Processing Record 4 of Set 6 | bengkulu
# Processing Record 5 of Set 6 | tashtyp
# Processing Record 6 of Set 6 | hami
# Processing Record 7 of Set 6 | brae
# Processing Record 8 of Set 6 | san patricio
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | rawson
# Processing Record 11 of Set 6 | caravelas
# Processing Record 12 of Set 6 | korla
# Processing Record 13 of Set 6 | mtwara
# Processing Record 14 of Set 6 | hit
# Processing Record 15 of Set 6 | mazagao
# Processing Record 16 of Set 6 | taurage
# Processing Record 17 of Set 6 | yar-sale
# Processing Record 18 of Set 6 | kavieng
# Processing Record 19 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 6 | svetlogorsk
# Processing Record 21 of Set 6 | urengoy
# Processing Record 22 of Set 6 | raudeberg
# Processing Record 23 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 6 | petersburg
# Processing Record 25 of Set 6 | tasiilaq
# Processing Record 26 of Set 6 | barber
# Processing Record 27 of Set 6 | dawei
# Processing Record 28 of Set 6 | laguna
# Processing Record 29 of Set 6 | portland
# Processing Record 30 of Set 6 | bilma
# Processing Record 31 of Set 6 | qandala
# Processing Record 32 of Set 6 | ust-maya
# Processing Record 33 of Set 6 | penzance
# Processing Record 34 of Set 6 | maragogi
# Processing Record 35 of Set 6 | platanos
# Processing Record 36 of Set 6 | cherskiy
# Processing Record 37 of Set 6 | saldanha
# Processing Record 38 of Set 6 | nishihara
# Processing Record 39 of Set 6 | giyani
# Processing Record 40 of Set 6 | fonte boa
# Processing Record 41 of Set 6 | werota
# Processing Record 42 of Set 6 | deputatskiy
# Processing Record 43 of Set 6 | monrovia
# Processing Record 44 of Set 6 | tshela
# Processing Record 45 of Set 6 | havoysund
# Processing Record 46 of Set 6 | bolshoye bunkovo
# City not found. Skipping...
# Processing Record 47 of Set 6 | bemidji
# Processing Record 48 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 6 | bam
# Processing Record 0 of Set 7 | tyrma
# Processing Record 1 of Set 7 | villazon
# Processing Record 2 of Set 7 | aklavik
# Processing Record 3 of Set 7 | capao bonito
# Processing Record 4 of Set 7 | krasnoselkup
# Processing Record 5 of Set 7 | myitkyina
# Processing Record 6 of Set 7 | viedma
# Processing Record 7 of Set 7 | bethal
# Processing Record 8 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 7 | severo-kurilsk
# Processing Record 10 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 7 | senno
# Processing Record 13 of Set 7 | whitley bay
# Processing Record 14 of Set 7 | puerto vallarta
# Processing Record 15 of Set 7 | haapiti
# Processing Record 16 of Set 7 | salinopolis
# Processing Record 17 of Set 7 | bahia honda
# Processing Record 18 of Set 7 | port-gentil
# Processing Record 19 of Set 7 | san jeronimo
# Processing Record 20 of Set 7 | plettenberg bay
# Processing Record 21 of Set 7 | tevriz
# Processing Record 22 of Set 7 | ixtapa
# Processing Record 23 of Set 7 | sadovoye
# Processing Record 24 of Set 7 | nabire
# Processing Record 25 of Set 7 | hazorasp
# Processing Record 26 of Set 7 | tilichiki
# Processing Record 27 of Set 7 | fort morgan
# Processing Record 28 of Set 7 | bjala
# City not found. Skipping...
# Processing Record 29 of Set 7 | braganca
# Processing Record 30 of Set 7 | ulety
# Processing Record 31 of Set 7 | cantagallo
# Processing Record 32 of Set 7 | linares
# Processing Record 33 of Set 7 | ulagan
# Processing Record 34 of Set 7 | parfenyevo
# Processing Record 35 of Set 7 | vila
# Processing Record 36 of Set 7 | mitsamiouli
# Processing Record 37 of Set 7 | atar
# Processing Record 38 of Set 7 | ahipara
# Processing Record 39 of Set 7 | mahajanga
# Processing Record 40 of Set 7 | kedrovyy
# Processing Record 41 of Set 7 | kosh-agach
# Processing Record 42 of Set 7 | yurginskoye
# Processing Record 43 of Set 7 | taunggyi
# Processing Record 44 of Set 7 | sibu
# Processing Record 45 of Set 7 | lorengau
# Processing Record 46 of Set 7 | shingu
# Processing Record 47 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 7 | zhangjiakou
# Processing Record 49 of Set 7 | nanortalik
# Processing Record 0 of Set 8 | salsomaggiore terme
# Processing Record 1 of Set 8 | severnoye
# Processing Record 2 of Set 8 | manggar
# Processing Record 3 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 8 | chokwe
# Processing Record 5 of Set 8 | bloemhof
# Processing Record 6 of Set 8 | moron
# Processing Record 7 of Set 8 | isangel
# Processing Record 8 of Set 8 | swindon
# Processing Record 9 of Set 8 | bereda
# Processing Record 10 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 8 | pierre
# Processing Record 12 of Set 8 | nieuw amsterdam
# Processing Record 13 of Set 8 | dong xoai
# Processing Record 14 of Set 8 | vila franca do campo
# Processing Record 15 of Set 8 | carnarvon
# Processing Record 16 of Set 8 | makat
# Processing Record 17 of Set 8 | nybro
# Processing Record 18 of Set 8 | broken hill
# Processing Record 19 of Set 8 | san carlos
# Processing Record 20 of Set 8 | puerto lempira
# Processing Record 21 of Set 8 | aksarka
# Processing Record 22 of Set 8 | pingzhuang
# Processing Record 23 of Set 8 | pimentel
# Processing Record 24 of Set 8 | capitao poco
# Processing Record 25 of Set 8 | darnah
# Processing Record 26 of Set 8 | lulea
# Processing Record 27 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 8 | waipawa
# Processing Record 29 of Set 8 | port lincoln
# Processing Record 30 of Set 8 | waitati
# Processing Record 31 of Set 8 | jibuti
# Processing Record 32 of Set 8 | kitui
# Processing Record 33 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 8 | ballina
# Processing Record 35 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 36 of Set 8 | limoeiro de anadia
# Processing Record 37 of Set 8 | pacifica
# Processing Record 38 of Set 8 | pangnirtung
# Processing Record 39 of Set 8 | gizo
# Processing Record 40 of Set 8 | natal
# Processing Record 41 of Set 8 | petatlan
# Processing Record 42 of Set 8 | hambantota
# Processing Record 43 of Set 8 | lethem
# Processing Record 44 of Set 8 | vazante
# Processing Record 45 of Set 8 | hualmay
# Processing Record 46 of Set 8 | cotoca
# Processing Record 47 of Set 8 | bathsheba
# Processing Record 48 of Set 8 | zambezi
# Processing Record 49 of Set 8 | metro
# Processing Record 0 of Set 9 | morros
# Processing Record 1 of Set 9 | jalu
# Processing Record 2 of Set 9 | syumsi
# Processing Record 3 of Set 9 | necochea
# Processing Record 4 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 5 of Set 9 | pevek
# Processing Record 6 of Set 9 | limoeiro do ajuru
# Processing Record 7 of Set 9 | coihaique
# Processing Record 8 of Set 9 | dicabisagan
# Processing Record 9 of Set 9 | narasannapeta
# Processing Record 10 of Set 9 | ankazobe
# Processing Record 11 of Set 9 | nushki
# Processing Record 12 of Set 9 | afanasyevo
# City not found. Skipping...
# Processing Record 13 of Set 9 | sete lagoas
# Processing Record 14 of Set 9 | chabahar
# Processing Record 15 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 9 | pokrovskoye
# Processing Record 17 of Set 9 | bonoua
# Processing Record 18 of Set 9 | seminole
# Processing Record 19 of Set 9 | tambura
# Processing Record 20 of Set 9 | balkanabat
# Processing Record 21 of Set 9 | nakhon si thammarat
# Processing Record 22 of Set 9 | berdigestyakh
# Processing Record 23 of Set 9 | bubaque
# Processing Record 24 of Set 9 | berlevag
# Processing Record 25 of Set 9 | batagay
# Processing Record 26 of Set 9 | kenai
# Processing Record 27 of Set 9 | vilani
# Processing Record 28 of Set 9 | terre haute
# Processing Record 29 of Set 9 | kloulklubed
# Processing Record 30 of Set 9 | airai
# Processing Record 31 of Set 9 | guerrero negro
# Processing Record 32 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 9 | labuhan
# Processing Record 34 of Set 9 | leningradskiy
# Processing Record 35 of Set 9 | zhigansk
# Processing Record 36 of Set 9 | praya
# Processing Record 37 of Set 9 | chico
# Processing Record 38 of Set 9 | dharchula
# Processing Record 39 of Set 9 | ust-nera
# Processing Record 40 of Set 9 | saint anthony
# Processing Record 41 of Set 9 | mucurapo
# Processing Record 42 of Set 9 | villa literno
# Processing Record 43 of Set 9 | maniitsoq
# Processing Record 44 of Set 9 | prince george
# Processing Record 45 of Set 9 | palu
# Processing Record 46 of Set 9 | takoradi
# Processing Record 47 of Set 9 | tome
# Processing Record 48 of Set 9 | fereydunshahr
# Processing Record 49 of Set 9 | tezu
# Processing Record 0 of Set 10 | khani
# Processing Record 1 of Set 10 | haines junction
# Processing Record 2 of Set 10 | severnyy
# Processing Record 3 of Set 10 | port-cartier
# Processing Record 4 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 5 of Set 10 | kondinskoye
# Processing Record 6 of Set 10 | cananeia
# Processing Record 7 of Set 10 | galle
# Processing Record 8 of Set 10 | seoul
# Processing Record 9 of Set 10 | atherton
# Processing Record 10 of Set 10 | erzin
# Processing Record 11 of Set 10 | candawaga
# City not found. Skipping...
# Processing Record 12 of Set 10 | isla mujeres
# Processing Record 13 of Set 10 | nouakchott
# Processing Record 14 of Set 10 | port blair
# Processing Record 15 of Set 10 | progreso
# Processing Record 16 of Set 10 | araouane
# Processing Record 17 of Set 10 | muros
# Processing Record 18 of Set 10 | shenjiamen
# Processing Record 19 of Set 10 | saint-pierre
# Processing Record 20 of Set 10 | curup
# Processing Record 21 of Set 10 | sao filipe
# Processing Record 22 of Set 10 | melfi
# Processing Record 23 of Set 10 | puerto cortes
# City not found. Skipping...
# Processing Record 24 of Set 10 | poum
# Processing Record 25 of Set 10 | batemans bay
# Processing Record 26 of Set 10 | broome
# Processing Record 27 of Set 10 | choucheng
# City not found. Skipping...
# Processing Record 28 of Set 10 | thai binh
# Processing Record 29 of Set 10 | sitka
# Processing Record 30 of Set 10 | kupang
# Processing Record 31 of Set 10 | magadan
# Processing Record 32 of Set 10 | flin flon
# Processing Record 33 of Set 10 | beringovskiy
# Processing Record 34 of Set 10 | egvekinot
# Processing Record 35 of Set 10 | harindanga
# Processing Record 36 of Set 10 | anaconda
# Processing Record 37 of Set 10 | khandyga
# Processing Record 38 of Set 10 | minbu
# Processing Record 39 of Set 10 | tabuk
# Processing Record 40 of Set 10 | sladkovo
# Processing Record 41 of Set 10 | erenhot
# Processing Record 42 of Set 10 | bilibino
# Processing Record 43 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 44 of Set 10 | hunchun
# Processing Record 45 of Set 10 | hobyo
# Processing Record 46 of Set 10 | pangody
# Processing Record 47 of Set 10 | bom jesus
# Processing Record 48 of Set 10 | yuzhno-kurilsk
# Processing Record 49 of Set 10 | sibiti
# Processing Record 0 of Set 11 | grand-santi
# Processing Record 1 of Set 11 | marawi
# Processing Record 2 of Set 11 | sovetskiy
# Processing Record 3 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 4 of Set 11 | ilebo
# Processing Record 5 of Set 11 | jennings
# Processing Record 6 of Set 11 | tigil
# Processing Record 7 of Set 11 | asosa
# Processing Record 8 of Set 11 | backa palanka
# Processing Record 9 of Set 11 | vila velha
# Processing Record 10 of Set 11 | krasnyy yar
# Processing Record 11 of Set 11 | asfi
# Processing Record 12 of Set 11 | te anau
# Processing Record 13 of Set 11 | tiksi
# Processing Record 14 of Set 11 | oussouye
# Processing Record 15 of Set 11 | rio grande
# Processing Record 16 of Set 11 | monte cristi
# City not found. Skipping...
# Processing Record 17 of Set 11 | huarmey
# Processing Record 18 of Set 11 | cooma
# Processing Record 19 of Set 11 | nador
# Processing Record 20 of Set 11 | mawlaik
# Processing Record 21 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 22 of Set 11 | xuddur
# Processing Record 23 of Set 11 | bahia blanca
# Processing Record 24 of Set 11 | road town
# Processing Record 25 of Set 11 | mariakani
# Processing Record 26 of Set 11 | rusape
# Processing Record 27 of Set 11 | shebunino
# Processing Record 28 of Set 11 | kudahuvadhoo
# Processing Record 29 of Set 11 | kavaratti
# Processing Record 30 of Set 11 | lumajang
# Processing Record 31 of Set 11 | gainesville
# Processing Record 32 of Set 11 | port macquarie
# Processing Record 33 of Set 11 | thunder bay
# Processing Record 34 of Set 11 | vestmannaeyjar
# Processing Record 35 of Set 11 | formosa
# Processing Record 36 of Set 11 | ambon
# Processing Record 37 of Set 11 | dong hoi
# Processing Record 38 of Set 11 | vintileasca
# Processing Record 39 of Set 11 | sisimiut
# Processing Record 40 of Set 11 | srednekolymsk
# Processing Record 41 of Set 11 | samarai
# Processing Record 42 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 11 | laem sing
# Processing Record 44 of Set 11 | lata
# Processing Record 45 of Set 11 | san juan
# Processing Record 46 of Set 11 | jumla
# Processing Record 47 of Set 11 | lamu
# Processing Record 48 of Set 11 | kapit
# Processing Record 49 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 0 of Set 12 | alice springs
# Processing Record 1 of Set 12 | sangar
# Processing Record 2 of Set 12 | buin
# Processing Record 3 of Set 12 | cockburn town
# Processing Record 4 of Set 12 | windhoek
# Processing Record 5 of Set 12 | maxixe
# Processing Record 6 of Set 12 | rudsar
# Processing Record 7 of Set 12 | grigoropolisskaya
# Processing Record 8 of Set 12 | manta
# Processing Record 9 of Set 12 | meulaboh
# Processing Record 10 of Set 12 | khavarion
# City not found. Skipping...
# Processing Record 11 of Set 12 | pyay
# Processing Record 12 of Set 12 | awjilah
# Processing Record 13 of Set 12 | paramonga
# Processing Record 14 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 12 | pirgos
# Processing Record 16 of Set 12 | manzanillo
# Processing Record 17 of Set 12 | camacha
# Processing Record 18 of Set 12 | hay river
# Processing Record 19 of Set 12 | verkhnevilyuysk
# Processing Record 20 of Set 12 | acarau
# Processing Record 21 of Set 12 | kabalo
# Processing Record 22 of Set 12 | ancud
# Processing Record 23 of Set 12 | dunedin
# Processing Record 24 of Set 12 | chengde
# Processing Record 25 of Set 12 | northam
# Processing Record 26 of Set 12 | genhe
# Processing Record 27 of Set 12 | lazarev
# Processing Record 28 of Set 12 | miri
# Processing Record 29 of Set 12 | abapo
# Processing Record 30 of Set 12 | mehamn
# Processing Record 31 of Set 12 | menongue
# Processing Record 32 of Set 12 | payson
# Processing Record 33 of Set 12 | znamenskoye
# Processing Record 34 of Set 12 | severo-yeniseyskiy
# Processing Record 35 of Set 12 | haimen
# Processing Record 36 of Set 12 | morondava
# Processing Record 37 of Set 12 | ardahan
# Processing Record 38 of Set 12 | ketou
# Processing Record 39 of Set 12 | karasjok
# Processing Record 40 of Set 12 | moyale
# Processing Record 41 of Set 12 | axim
# Processing Record 42 of Set 12 | rohtak
# Processing Record 43 of Set 12 | along
# Processing Record 44 of Set 12 | asau
# Processing Record 45 of Set 12 | presidencia roque saenz pena
# Processing Record 46 of Set 12 | nakhon thai
# Processing Record 47 of Set 12 | los llanos de aridane
# Processing Record 48 of Set 12 | kuito
# Processing Record 49 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 0 of Set 13 | flekkefjord
# Processing Record 1 of Set 13 | jabinyanah
# Processing Record 2 of Set 13 | pemba
# Processing Record 3 of Set 13 | marzuq
# Processing Record 4 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 5 of Set 13 | taloqan
# Processing Record 6 of Set 13 | akyab
# Processing Record 7 of Set 13 | daru
# Processing Record 8 of Set 13 | alice
# Processing Record 9 of Set 13 | inza
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          554
# Lat           554
# Lng           554
# Max Temp      554
# Humidity      554
# Cloudiness    554
# Wind Speed    554
# Country       554
# Date          554
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        buchanan   5.8808  -10.0467     25.09        92         100
# 1        klaksvik  62.2266   -6.5890      7.74        82         100
# 2       mahebourg -20.4081   57.7000     27.16        78          40
# 3          mitzic   0.7821   11.5490     20.45        95          97
# 4  cabo san lucas  22.8909 -109.9124     20.28        44          84
#
#    Wind Speed Country        Date
# 0        2.14      LR  1675829573
# 1       25.55      FO  1675829574
# 2        5.14      MU  1675829574
# 3        0.98      GA  1675829575
# 4        2.07      MX  1675829576

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              buchanan   5.8808  -10.0467     25.09        92         100
# 1              klaksvik  62.2266   -6.5890      7.74        82         100
# 2             mahebourg -20.4081   57.7000     27.16        78          40
# 3                mitzic   0.7821   11.5490     20.45        95          97
# 4        cabo san lucas  22.8909 -109.9124     20.28        44          84
#
#          Wind Speed Country        Date
# City_ID
# 0              2.14      LR  1675829573
# 1             25.55      FO  1675829574
# 2              5.14      MU  1675829574
# 3              0.98      GA  1675829575
# 4              2.07      MX  1675829576

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker="o", edgecolors="black", s=city_lat, alpha=0.75)


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Latitude vs. Max Temperature')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], marker="o", edgecolors="black", s=city_lat, alpha=0.75)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], marker="o", edgecolors="black", s=city_lat, alpha=0.75)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], marker="o", edgecolors="black", s=city_lat, alpha=0.75)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs. Wind Speed')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               buchanan   5.8808  -10.0467     25.09        92         100
# 1               klaksvik  62.2266   -6.5890      7.74        82         100
# 3                 mitzic   0.7821   11.5490     20.45        95          97
# 4         cabo san lucas  22.8909 -109.9124     20.28        44          84
# 8        puerto princesa   9.7392  118.7353     27.90        73         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.14      LR  1675829573
# 1             25.55      FO  1675829574
# 3              0.98      GA  1675829575
# 4              2.07      MX  1675829576
# 8              4.13      PH  1675829578

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           mahebourg -20.4081   57.7000     27.16        78          40
# 5              atuona  -9.8000 -139.0333     26.13        76          22
# 6             ushuaia -54.8000  -68.3000      8.79        91          99
# 7        punta arenas -53.1500  -70.9167     13.06        71           0
# 10         nelson bay -32.7167  152.1500     28.03        62          39
#
#          Wind Speed Country        Date
# City_ID
# 2              5.14      MU  1675829574
# 5              7.43      PF  1675829576
# 6              3.44      AR  1675829577
# 7              6.69      CL  1675829577
# 10             7.60      AU  1675829579

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_1 = northern_hemi_df['Lat']
y_1 = northern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_1, y_1)
regress_values = x_1 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_1,y_1)
plt.plot(x_1,regress_values,"r-")
plt.annotate(line_eq,(5.8,-22),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7804581172676067

# %%
# Linear regression on Southern Hemisphere
x_2 = southern_hemi_df['Lat']
y_2 = southern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_2, y_2)
regress_values = x_2 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_2,y_2)
plt.plot(x_2,regress_values,"r-")
plt.annotate(line_eq,(-20,10),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.16699445257420184

# %% [markdown]
# **Discussion about the linear relationship:** In the Northwest hempisphere as latitude goes up the maximum temperature goes down. The linear coefficient in the Northern hempisphere is -.83 which supports this correlation. In the Southern hempisphere the linear coefficient is .15, which does not indicate any correlation between max temp and latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_value,y_value)
plt.plot(x_value,regress_values,"r-")
plt.annotate(line_eq,(45,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.1939745685674687

# %%
# Southern Hemisphere
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_value,y_value)
plt.plot(x_value,regress_values,"r-")
plt.annotate(line_eq,(-26,38),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.16042317714851215

# %% [markdown]
# **Discussion about the linear relationship:**
# The linear regression of humidity vs latitude in both Northwern and Southern hempispheres show positive linear coefficients. As the latitiude increases the humidity also increases in both hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_value,y_value)
plt.plot(x_value,regress_values,"r-")
plt.annotate(line_eq,(40,55),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.09385527652221125

# %%
# Southern Hemisphere
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_value,y_value)
plt.plot(x_value,regress_values,"r-")
plt.annotate(line_eq,(-25,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.2154830197838764

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression of cloudiness vs latitude show positive coefficients for both Northern and Southern hempispheres. The dots are too scattered on the plots to indicate any relationship.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,2))

plt.scatter(x_value,y_value)
plt.plot(x_value,regress_values,"r-")
plt.annotate(line_eq,(10,13),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00412872297961602

# %%
# Southern Hemisphere
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_value,y_value)
plt.plot(x_value,regress_values,"r-")
plt.annotate(line_eq,(-50,8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.09757575826222442

# %% [markdown]
# **Discussion about the linear relationship:** In both hemispheres, the coefficinets are close to zero which indicates there is no strong relationship between wind speed and latitude.
